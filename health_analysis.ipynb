# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

pd.options.display.max_rows = 20
pd.options.display.float_format = "{:,.2f}".format

# %%
## ladda in data
file_path = "health_study_dataset.csv"
df = pd.read_csv(file_path)

df.head()

# %% [markdown]
# Vi börjar med att titta på de första fem raderna i datasetet. Det ger en snabb överblick över kolumnerna: ålder, kön, längd, vikt, blodtryck, kolesterol, rökstatus och sjukdom.

# %%
## Grundläggade information och null_värden 
df.info()

# %% [markdown]
# Datasetet innehåller 800 rader och 9 kolumner. Alla kolumner har kompletta värden (inga nulls). Variablerna är av typerna:
# - `int64`: id, age, disease
# - `float64`: height, weight, systolic_bp, cholesterol
# - `object`: sex, smoker
